# %% [markdown]
# # 04 Regression
#
# 로그 변환된 누적 관객 수를 예측하고 원래 관객 수 단위로 평가합니다.

# %%
from pathlib import Path
import subprocess
import sys

ROOT = Path.cwd()
if ROOT.name == 'notebooks':
    ROOT = ROOT.parent

subprocess.run([
    sys.executable,
    str(ROOT / 'src/train_regression.py'),
    '--input', str(ROOT / 'data/processed/movie_features.csv'),
], check=True, cwd=ROOT)

# %%
import pandas as pd
metrics = pd.read_csv(ROOT / 'outputs/metrics/regression_metrics.csv', encoding='utf-8-sig')
metrics.sort_values('rmse')
