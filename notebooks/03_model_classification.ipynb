# %% [markdown]
# # 03 Classification
#
# 메타데이터, 제목, 포스터 특성 조합별 분류 성능을 비교합니다.

# %%
from pathlib import Path
import subprocess
import sys

ROOT = Path.cwd()
if ROOT.name == 'notebooks':
    ROOT = ROOT.parent

subprocess.run([
    sys.executable,
    str(ROOT / 'src/train_classification.py'),
    '--input', str(ROOT / 'data/processed/movie_features.csv'),
    '--target', 'is_success_3000000',
], check=True, cwd=ROOT)

# %%
import pandas as pd
metrics = pd.read_csv(ROOT / 'outputs/metrics/classification_metrics.csv', encoding='utf-8-sig')
metrics.sort_values('f1', ascending=False)
